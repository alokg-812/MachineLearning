# %% [markdown]
# CSV & text files

# %%
import pandas as pd

# %%
df = pd.read_csv('cardekho_dataset.csv')

# %%
df1 = pd.read_json('unece.json')

# %%
df2 = pd.read_csv('COVID19Cases.csv')
# Out:
# C:\Users\alokg\AppData\Local\Temp\ipykernel_12712\1437218496.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('COVID19Cases.csv')

# %%
df2
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# 950668  Confirmed                        NaN      0           0  1/22/2020
# 950669  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %%
df1
# Out:
#         Country  Year  Area (square kilometres)  Total population  \
# 0       Albania  2000                   28748.0         3401198.0
# 1       Albania  2001                   28748.0         3073734.0
# 2       Albania  2002                   28748.0         3093465.0
# 3       Albania  2003                   28748.0         3111162.0
# 4       Albania  2004                   28748.0         3127264.0
# ..          ...   ...                       ...               ...
# 879  Uzbekistan  2012                  447400.0        29774448.0
# 880  Uzbekistan  2013                  447400.0        30243172.0
# 881  Uzbekistan  2014                  447400.0        30757669.0
# 882  Uzbekistan  2015                  447400.0        31298929.0
# 883  Uzbekistan  2016                  447400.0               NaN
#
#      Population density, pers. per sq. km  Population aged 0-14, male  \
# 0                               118.31077                    564851.0
# ...

# %%
df
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
df3 = pd.read_excel('titanic_modified_NA.xlsx')

# %%
df3
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/pwskills123/pwioidatascience/main/pandas/cardekho_dataset.csv')

# %%
df4
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
df3.Survived.value_counts().sum()
# Out:
# 891

# %%
df5 = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area')

# %%
df5
# Out:
# [                                0
#  0  Countries of the world by area,
#      Unnamed: 0                     Country / dependency  \
#  0          NaN                                    Earth
#  1            1                                   Russia
#  2          NaN                               Antarctica
#  3            2                                   Canada
#  4      3/4 [e]                                    China
#  ..         ...                                      ...
#  259        NaN  Ashmore and Cartier Islands (Australia)
#  260        NaN            Coral Sea Islands (Australia)
#  261        NaN               Spratly Islands (disputed)
#  262        194                                   Monaco
#  263        195                             Vatican City
#
#              Total in km2 (mi2)         Land in km2 (mi2)  \
#  0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
#  1       17,098,246 (6,601,667)    16,376,870 (6,323,142)
# ...

# %%
df5[1]
# Out:
#     Unnamed: 0                     Country / dependency  \
# 0          NaN                                    Earth
# 1            1                                   Russia
# 2          NaN                               Antarctica
# 3            2                                   Canada
# 4      3/4 [e]                                    China
# ..         ...                                      ...
# 259        NaN  Ashmore and Cartier Islands (Australia)
# 260        NaN            Coral Sea Islands (Australia)
# 261        NaN               Spratly Islands (disputed)
# 262        194                                   Monaco
# 263        195                             Vatican City
#
#             Total in km2 (mi2)         Land in km2 (mi2)  \
# 0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
# 1       17,098,246 (6,601,667)    16,376,870 (6,323,142)
# 2       14,200,000 (5,480,000)    14,200,000 (5,480,000)
# 3        9,984,670 (3,855,100)     9,093,507 (3,511,021)
# ...

# %%
len(df5)
# Out:
# 4

# %%
df5[2]
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteLists of countries by geographical rankings  \
# 0                                               Area
# 1  1989 Exclusive economic zone Forest Irrigated ...
# ...

# %%
df5[3]
# Out:
#                                                    0  \
# 0  1989 Exclusive economic zone Forest Irrigated ...
# 1                                          Continent
#
#                                                    1
# 0  1989 Exclusive economic zone Forest Irrigated ...
# 1  Africa Asia Europe North America Oceania South...

# %%
df5[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df5[4]
#
# IndexError: list index out of range

# %%
df5[0]
# Out:
#                                 0
# 0  Countries of the world by area

# %%
df2
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# 950668  Confirmed                        NaN      0           0  1/22/2020
# 950669  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %%
df2.Cases.value_counts()
# Out:
# Cases
# 0         608678
# 1          52885
# 2          27594
# 3          19077
# 4          13880
#            ...
# 3866           1
# 117589         1
# 15131          1
# 29684          1
# 2529           1
# Name: count, Length: 9985, dtype: int64

# %%
df2.Difference.value_counts()
# Out:
# Difference
# 0       805326
# 1        44307
# 2        19530
# 3        11284
# 4         7828
#          ...
# 1552         1
# 732          1
# 3403         1
# 1625         1
# 1448         1
# Name: count, Length: 2136, dtype: int64

# %%
df2.Cases.describe()
# Out:
# count    950670.000000
# mean        273.518654
# std        5187.497792
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max      614941.000000
# Name: Cases, dtype: float64

# %%
df2.Differnce.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12712\1501398845.py in ?()
# ----> 1 df2.Differnce.describe()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Differnce'

# %%
df2.Combined_Key.describe()
# Out:
# count             950670
# unique              3521
# top       Western Sahara
# freq                 270
# Name: Combined_Key, dtype: object

# %%
df2.Country_Region.describe()
# Out:
# count     950670
# unique       187
# top           US
# freq      879930
# Name: Country_Region, dtype: object

# %%
df2.Country_Region.is_unique
# Out:
# False

# %%
df2.Case_Type.describe()
# Out:
# count        950670
# unique            2
# top       Confirmed
# freq         475335
# Name: Case_Type, dtype: object

# %%
df2.Cases.describe().max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of count    950670.000000
# mean        273.518654
# std        5187.497792
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           4.000000
# max      614941.000000
# Name: Cases, dtype: float64>

# %%
df2.FIPS.describe()
# Out:
# count    849690.000000
# mean      30335.484906
# std       15196.097280
# min          60.000000
# 25%       18169.000000
# 50%       29171.000000
# 75%       45079.000000
# max       56045.000000
# Name: FIPS, dtype: float64

# %%
df2.Cases.sum()
# Out:
# 260025979
